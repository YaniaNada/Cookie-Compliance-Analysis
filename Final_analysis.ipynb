# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

raw_data = pd.read_excel('epitech_cookie_compliance.xlsx')

# %%
# Making a copy of the raw data to work with
df = raw_data.copy()
df.head(3)
# Out:
#    Cookie ID          Cookie Name          Domain  \
# 0          1  Chocolate Crinkle_2     spxflow.com
# 1          2          Nankhatai_1     hitachi.com
# 2          3    Chocolate Wafer_6  electrolux.com
#
#    Expires / Max-Age (in seconds)       Origin  \
# 0                        60478299  First-party
# 1                               0  First-party
# 2                              -1  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
# 2                                               True             Functional
#
#                                      Data Collected   Secure  HttpOnly  ...  \
# 0  Network Type; IP Address; Referring URL; Adver...   False      True  ...
# 1  Advertising Preferences; Device Information; V...   False     False  ...
# 2  Flash Version; Referring URL; Operating System...   False      True  ...
#
#   SameSite       Path Consent Required Creation Date Last Accessed  Priority  \
# 0   Strict          /             True    03/03/2024    08/10/2024       Low
# 1   Strict  /products             True    01/14/2024    08/02/2024       Low
# 2      Lax      /user             True    09/07/2024    10/12/2024       Low
#
#   Partitioned Size (KB)    Duration  Host Only
# 0        True       7.6  Persistent      False
# 1       False       6.3  Persistent       True
# 2       False       2.4     Session      False
#
# [3 rows x 23 columns]

# %%
# checking for duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# checking for nulls
df.isnull().sum()
# Out:
# Cookie ID                                                         0
# Cookie Name                                                       0
# Domain                                                            0
# Expires / Max-Age (in seconds)                                    0
# Origin                                                            0
# SameParty (if cookie keeps data locally or sends it outside)      0
# Purpose                                                           0
# Data Collected                                                    0
# Secure                                                            0
# HttpOnly                                                          0
# Cookie Policy                                                     0
# Cookie Banner                                                     0
# Cookie Options                                                   66
# SameSite                                                        186
# Path                                                              0
# Consent Required                                                  0
# Creation Date                                                     0
# Last Accessed                                                     0
# Priority                                                          0
# Partitioned                                                       0
# Size (KB)                                                         0
# Duration                                                          0
# Host Only                                                         0
# dtype: int64

# %%
# Clean and transform
def clean_and_transform(df):
    # Dropping irrelevant fields
    df.drop(['Cookie Name','Domain','Secure', 'HttpOnly', 'SameSite', 'Path', 'Priority', 'Partitioned','Creation Date', 'Last Accessed', 'Size (KB)', 'Host Only'], axis = 1, inplace = True)
    
    # cookies expiration period converted from seconds to years
    df['expiration (in years)'] = (((df['Expires / Max-Age (in seconds)']/60)/60)/24)/365

    return df

clean_and_transform(df)
df.head(2)
# Out:
#    Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0          1                        60478299  First-party
# 1          2                               0  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
#
#                                      Data Collected   \
# 0  Network Type; IP Address; Referring URL; Adver...
# 1  Advertising Preferences; Device Information; V...
#
#                                        Cookie Policy  Cookie Banner  \
# 0  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
#
#                                Cookie Options  Consent Required    Duration  \
# 0  Decline All, Accept All, Customize cookies              True  Persistent
# 1               Accept All, Customize cookies              True  Persistent
#
#    expiration (in years)
# 0               1.917754
# 1               0.000000

# %%
# Check: Cookie retention compliance
def is_retention_compliant(df):
    df['Retention compliant'] = ((df['Duration'] == 'Session')&(df['expiration (in years)'] <1))|((df['Duration'] == 'Persistent')&(df['expiration (in years)'] < 2))
    return df

is_retention_compliant(df)
df.head(2)
# Out:
#    Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0          1                        60478299  First-party
# 1          2                               0  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
#
#                                      Data Collected   \
# 0  Network Type; IP Address; Referring URL; Adver...
# 1  Advertising Preferences; Device Information; V...
#
#                                        Cookie Policy  Cookie Banner  \
# 0  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
#
#                                Cookie Options  Consent Required    Duration  \
# 0  Decline All, Accept All, Customize cookies              True  Persistent
# 1               Accept All, Customize cookies              True  Persistent
#
#    expiration (in years)  Retention compliant
# 0               1.917754                 True
# 1               0.000000                 True

# %%
# Split into essential and non-essential based on purpose
essential_purposes = {'Functional', 'Operational Efficiency', 'Legal Obligations', 'Compliance', 'Fraud Prevention', 'Security'}
non_essential_purposes = {'Analytics', 'Service Improvement',
       'Content Customization', 'Advertising', 'Customer Support',
       'Tracking', 'Social Media','Personalization', 'E-commerce', 'Compliance',
       'Performance Monitoring', 'Market Research', 'User Experience',
       'Customer Feedback'}

def split_essential_and_non_essential(df):
    alist = []
    for i in range(len(df)):       
        if df['Purpose'][i] in essential_purposes:
            alist.append('Essential')
            
        else:
            alist.append('Non-Essential')
    df['Essential/Non-essential'] = alist
    return df

split_essential_and_non_essential(df)
df.head(2)
# Out:
#    Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0          1                        60478299  First-party
# 1          2                               0  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
#
#                                      Data Collected   \
# 0  Network Type; IP Address; Referring URL; Adver...
# 1  Advertising Preferences; Device Information; V...
#
#                                        Cookie Policy  Cookie Banner  \
# 0  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
#
#                                Cookie Options  Consent Required    Duration  \
# 0  Decline All, Accept All, Customize cookies              True  Persistent
# 1               Accept All, Customize cookies              True  Persistent
#
#    expiration (in years)  Retention compliant Essential/Non-essential
# 0               1.917754                 True               Essential
# 1               0.000000                 True           Non-Essential

# %%
# Key options required in the banner
required_options = {'Decline All', 'Accept All', 'Customize'}

# Check: Cookie banner compliance for non-essential cookies
def is_banner_compliant(df):
    
   alist=[]
   for i in range(len(df)):      
      if (df['Essential/Non-essential'][i]== 'Non-Essential')&(df['Cookie Banner'][i] == True):
         x= df['Cookie Options'][i]
         if required_options.issubset(x):
            alist.append(True)
         else:
            alist.append(False)
      else:
         alist.append(True)

   df['Banner_compliant'] = alist
   return df

is_banner_compliant(df)
df.head(3)
# Out:
#    Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0          1                        60478299  First-party
# 1          2                               0  First-party
# 2          3                              -1  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
# 2                                               True             Functional
#
#                                      Data Collected   \
# 0  Network Type; IP Address; Referring URL; Adver...
# 1  Advertising Preferences; Device Information; V...
# 2  Flash Version; Referring URL; Operating System...
#
#                                        Cookie Policy  Cookie Banner  \
# 0  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 2  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
#
#                                Cookie Options  Consent Required    Duration  \
# 0  Decline All, Accept All, Customize cookies              True  Persistent
# 1               Accept All, Customize cookies              True  Persistent
# 2  Decline All, Accept All, Customize cookies              True     Session
#
#    expiration (in years)  Retention compliant Essential/Non-essential  \
# 0           1.917754e+00                 True               Essential
# 1           0.000000e+00                 True           Non-Essential
# 2          -3.170979e-08                 True               Essential
#
#    Banner_compliant
# 0              True
# 1             False
# 2              True

# %%
# Key phrases to check for policy compliance
policy_essential = {'Types of CookiesHere are some examples of the types of cookies we use:', 'Cookie Origin'}
policy_third_party = {'Third-Party Processing'}
policy_non_essential = {'Types of CookiesHere are some examples of the types of cookies we use:', 'Cookie Origin', 'Third-Party Processing', 'Consent','Managing Cookies', 'What Are Your Rights'}

# Check: Cookie policy compliance
def is_policy_compliant(df): 
    alist = []
    for i in range(len(df['Cookie Policy'])):
        x = {df['Cookie Policy'][i]}
        x= df['Cookie Policy'].str.split('\n')[i] 
        
        if df['Essential/Non-essential'][i]=='Essential':
            if (df['Origin'][i] == 'First-party')&(policy_essential.issubset(x)):
                alist.append(True)
            elif (df['Origin'][i] == 'Third-party')&((policy_essential & policy_third_party).issubset(x)):
                alist.append(True)
            else:
                alist.append(False)

        elif df['Essential/Non-essential'][i]=='Non-Essential':
            if (df['Origin'][i] == 'First-party')&(policy_non_essential.issubset(x)):
                alist.append(True)
            elif (df['Origin'][i] == 'Third-party')&((policy_non_essential & policy_third_party).issubset(x)):
                alist.append(True)
            else:
                alist.append(False)

    df['Policy compliant'] = alist  
    return df

is_policy_compliant(df)
df.head(2)
# Out:
#    Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0          1                        60478299  First-party
# 1          2                               0  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
#
#                                      Data Collected   \
# 0  Network Type; IP Address; Referring URL; Adver...
# 1  Advertising Preferences; Device Information; V...
#
#                                        Cookie Policy  Cookie Banner  \
# 0  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
#
#                                Cookie Options  Consent Required    Duration  \
# 0  Decline All, Accept All, Customize cookies              True  Persistent
# 1               Accept All, Customize cookies              True  Persistent
#
#    expiration (in years)  Retention compliant Essential/Non-essential  \
# 0               1.917754                 True               Essential
# 1               0.000000                 True           Non-Essential
#
#    Banner_compliant  Policy compliant
# 0              True             False
# 1             False              True

# %%
# Final Compliance Check

def total_compliance_check(df):
    alist=[]
    for i in range(len(df)):
        if df['Retention compliant'][i]==True:
            if df['Banner_compliant'][i]==True:
                if df['Policy compliant'][i]==True:
                    alist.append(True)
                else:
                    alist.append(False)
            else:
                alist.append(False)
        else:
            alist.append(False)
    df['Is compliant'] = alist

    return df

total_compliance_check(df)
df.head(3)
# Out:
#    Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0          1                        60478299  First-party
# 1          2                               0  First-party
# 2          3                              -1  First-party
#
#    SameParty (if cookie keeps data locally or sends it outside)     Purpose  \
# 0                                               True             Functional
# 1                                               True              Analytics
# 2                                               True             Functional
#
#                                      Data Collected   \
# 0  Network Type; IP Address; Referring URL; Adver...
# 1  Advertising Preferences; Device Information; V...
# 2  Flash Version; Referring URL; Operating System...
#
#                                        Cookie Policy  Cookie Banner  \
# 0  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 2  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
#
#                                Cookie Options  Consent Required    Duration  \
# 0  Decline All, Accept All, Customize cookies              True  Persistent
# 1               Accept All, Customize cookies              True  Persistent
# 2  Decline All, Accept All, Customize cookies              True     Session
#
#    expiration (in years)  Retention compliant Essential/Non-essential  \
# 0           1.917754e+00                 True               Essential
# 1           0.000000e+00                 True           Non-Essential
# 2          -3.170979e-08                 True               Essential
#
#    Banner_compliant  Policy compliant  Is compliant
# 0              True             False         False
# 1             False              True         False
# 2              True              True          True

# %%
# Summary of Compliance
compliance_summary = {
    'Total Cookies': len(df),
    'Session Cookies': (df['Duration']=='Session').sum(),
    'Persistent Cookies': (df['Duration']=='Persistent').sum(),
    'Essential Cookies': (df['Essential/Non-essential']=='Essential').sum(),
    'Non-Essential Cookies': (df['Essential/Non-essential']=='Non-Essential').sum(),
    'Compliant Cookies': (df['Is compliant']==True).sum(),
    'Non-Compliant Cookies': (df['Is compliant']==False).sum(),
    'Compliance Rate (%)': (((df['Is compliant']==True).sum())/(df['Is compliant'].count())) * 100
}

compliance_summary
# Out:
# {'Total Cookies': 750,
#  'Session Cookies': 379,
#  'Persistent Cookies': 371,
#  'Essential Cookies': 224,
#  'Non-Essential Cookies': 526,
#  'Compliant Cookies': 73,
#  'Non-Compliant Cookies': 677,
#  'Compliance Rate (%)': 9.733333333333333}

# %%
# Detailed breakdown of non-compliance reasons
non_compliant_cookies = df[df['Is compliant'] == False]

# %%
# Save the analyzed data to a CSV file
#cookies.to_csv(output_filename, index=False)
df.to_excel
# Out:
#      Cookie ID  Expires / Max-Age (in seconds)       Origin  \
# 0            1                        60478299  First-party
# 1            2                               0  First-party
# 3            4                               0  First-party
# 4            5                               0  First-party
# 5            6                       195683602  First-party
# ..         ...                             ...          ...
# 745        746                       145495670  First-party
# 746        747                        90423355  First-party
# 747        748                        60060267  First-party
# 748        749                              -1  Third-party
# 749        750                        48256813  First-party
#
#      SameParty (if cookie keeps data locally or sends it outside)  \
# 0                                                 True
# 1                                                 True
# 3                                                 True
# 4                                                 True
# 5                                                 True
# ..                                                 ...
# 745                                               True
# 746                                               True
# 747                                               True
# 748                                               True
# 749                                               True
#
#                     Purpose  \
# 0                Functional
# 1                 Analytics
# 3       Service Improvement
# 4     Content Customization
# 5               Advertising
# ..                      ...
# 745         Personalization
# 746                Tracking
# 747  Performance Monitoring
# 748       Customer Feedback
# 749             Advertising
#
#                                        Data Collected   \
# 0    Network Type; IP Address; Referring URL; Adver...
# 1    Advertising Preferences; Device Information; V...
# 3    Browser; Language Preferences; Download Histor...
# 4    Network Type; Visited Pages; Error Reports; Fl...
# 5    App Usage; Subscription Status; Payment Inform...
# ..                                                 ...
# 745  IP Address; Error Reports; App Usage; Time Spe...
# 746  Clickstream Data; JavaScript Enabled; Session ...
# 747  Subscription Status; Language Preferences; Bat...
# 748  Search Queries; Clickstream Data; App Usage; F...
# 749  Device Information; Local Time; JavaScript Ena...
#
#                                          Cookie Policy  Cookie Banner  \
# 0    Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 1    Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 3    Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 4    Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 5                                   No policy informed           True
# ..                                                 ...            ...
# 745  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 746  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 747  Cookie Policy\n\nIntroduction\nWe use cookies ...          False
# 748  Cookie Policy\n\nIntroduction\nWe use cookies ...           True
# 749                                 No policy informed           True
#
#                                  Cookie Options  Consent Required    Duration  \
# 0    Decline All, Accept All, Customize cookies              True  Persistent
# 1                 Accept All, Customize cookies              True  Persistent
# 3    Decline All, Accept All, Customize cookies              True     Session
# 4                                    Accept All              True     Session
# 5                 Accept All, Customize cookies              True     Session
# ..                                          ...               ...         ...
# 745                                  Accept All              True  Persistent
# 746  Decline All, Accept All, Customize cookies              True  Persistent
# 747                                         NaN              True  Persistent
# 748  Decline All, Accept All, Customize cookies              True  Persistent
# 749               Accept All, Customize cookies              True  Persistent
#
#      expiration (in years)  Retention compliant Essential/Non-essential  \
# 0             1.917754e+00                 True               Essential
# 1             0.000000e+00                 True           Non-Essential
# 3             0.000000e+00                 True           Non-Essential
# 4             0.000000e+00                 True           Non-Essential
# 5             6.205086e+00                False           Non-Essential
# ..                     ...                  ...                     ...
# 745           4.613637e+00                False           Non-Essential
# 746           2.867306e+00                False           Non-Essential
# 747           1.904499e+00                 True           Non-Essential
# 748          -3.170979e-08                 True           Non-Essential
# 749           1.530214e+00                 True           Non-Essential
#
#      Banner_compliant  Policy compliant  Is compliant
# 0                True             False         False
# 1               False              True         False
# 3               False             False         False
# 4               False             False         False
# 5               False             False         False
# ..                ...               ...           ...
# 745             False             False         False
# 746             False             False         False
# 747              True             False         False
# 748             False             False         False
# 749             False             False         False
#
# [677 rows x 17 columns]
